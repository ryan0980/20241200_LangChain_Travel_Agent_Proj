# %% [markdown]
# # Imports, Environment Setup, and LLM Initialization

# %%
import os
from dotenv import load_dotenv
import pandas as pd
import json
import textwrap
from typing_extensions import List, TypedDict
from langchain_openai import ChatOpenAI

# Load environment variables
load_dotenv()

print("OPENAI_API_KEY:", "*****" if os.getenv("OPENAI_API_KEY") else "Not Set")
print("LANGCHAIN_TRACING_V2:", os.getenv("LANGCHAIN_TRACING_V2"))
print("LANGCHAIN_ENDPOINT:", os.getenv("LANGCHAIN_ENDPOINT"))
print("LANGCHAIN_API_KEY:", "*****" if os.getenv("LANGCHAIN_API_KEY") else "Not Set")
print("LANGCHAIN_PROJECT:", os.getenv("LANGCHAIN_PROJECT"))
print("USER_AGENT:", os.getenv("USER_AGENT"))

# Initialize ChatOpenAI client
llm = ChatOpenAI(model="gpt-4", temperature=0)
# Out:
# OPENAI_API_KEY: *****
# LANGCHAIN_TRACING_V2: true
# LANGCHAIN_ENDPOINT: https://api.smith.langchain.com
# LANGCHAIN_API_KEY: *****
# LANGCHAIN_PROJECT: 20241209_Lang_Travel_V2
# USER_AGENT: None

# %%
def llm_intent_classification(question: str) -> bool:
    """
    Uses LLM to determine if the user's question is related to searching for hotels.
    Returns True if related to hotels, False otherwise.
    """
    prompt_text = f"""
    Please determine whether the following user question is related to searching for hotels.
    Answer with "Yes" or "No" only.

    User Question: "{question}"
    """
    response = llm.invoke(prompt_text)
    answer = response.content.strip().lower()
    print(f"Intent Classification Result: {answer.capitalize()}")
    return answer.startswith("y")

# Define application state
class State(TypedDict):
    question: str
    context: List[str]
    answer: str
    hotel_found: str  # Store the name of the found hotel if any

# %%
def load_data(file_path):
    """
    Loads the hotel dataset and cleans column names.
    """
    try:
        hotels_data = pd.read_csv(file_path, encoding="Windows-1252")
        hotels_data.columns = hotels_data.columns.str.strip()  # Clean column names
        print("--------------------------------------------------")
        print("Dataset loaded successfully!")
        print("Available columns in the dataset:")
        print(hotels_data.columns.tolist())
        print("--------------------------------------------------")
        return hotels_data
    except Exception as e:
        print(f"Error loading data: {e}")
        return None

def parse_user_input(user_input, column_names):
    """
    Uses LLM to extract filtering criteria and return fields.
    """
    one_shot_example = """
    Example User Input: "I want to find a hotel in London, with 3 star and wifi"
    Example Output: {
      "filters": {"cityName": "London", "HotelRating": "ThreeStar", "HotelFacilities": "Wifi"}
    }
    """

    prompt_text = f"""
    The dataset has the following columns: {column_names}
    Based on this, analyze the user's input and determine:
    1. The filtering criteria (e.g., "cityName": "New York").

    Provide your answer in JSON format like this:
    {{
      "filters": {{"column_name": "value", "another_column": "value"}}
    }}

    {one_shot_example}

    User Input: "{user_input}"
    """
    response = llm.invoke(prompt_text)
    response_content = response.content.strip()

    if "Output:" in response_content:
        response_content = response_content.split("Output:", 1)[1].strip()

    try:
        parsed_request = json.loads(response_content)
        return parsed_request
    except json.JSONDecodeError:
        print("--------------------------------------------------")
        print("Error parsing LLM response as JSON.")
        print("Please try rephrasing your query.")
        print("--------------------------------------------------")
        raise ValueError("LLM returned an invalid JSON response.")

def wrap_text_columns(df, columns_to_wrap, width=80):
    """
    Wrap text for specified columns to improve readability.
    """
    for col in columns_to_wrap:
        if col in df.columns:
            df[col] = df[col].astype(str).apply(lambda x: "\n".join(textwrap.wrap(x, width=width)))
    return df

def apply_filters(hotels_df, filters):
    """
    Apply filtering criteria to the dataset.
    """
    print("--------------------------------------------------")
    print("Applying filters to the dataset...")
    print("Current filters:", filters)
    filtered_df = hotels_df.copy()

    for column, value in filters.items():
        if column == "HotelFacilities" and isinstance(value, list):
            for condition in value:
                filtered_df = filtered_df[filtered_df[column].str.contains(condition, case=False, na=False)]
        else:
            filtered_df = filtered_df[filtered_df[column].str.contains(value, case=False, na=False)]

    result_fields = [
        "HotelName", "HotelRating", "Attractions", "Description",
        "HotelFacilities", "PhoneNumber", "HotelWebsiteUrl"
    ]
    result_fields = [f for f in result_fields if f in filtered_df.columns]
    result_df = filtered_df[result_fields]

    print(f"Number of results found: {len(result_df)}")

    columns_to_wrap = ["Description", "Attractions", "HotelFacilities"]
    result_df = wrap_text_columns(result_df, columns_to_wrap, width=80)

    if not result_df.empty:
        print("--------------------------------------------------")
        print("Sample of the matched results:")
        print(result_df.head().to_string(index=False))
    print("--------------------------------------------------")

    return result_df

def iterative_filtering(hotels_df, filters, column_names):
    """
    Iteratively refine results until one match remains.
    Maintains a record of at least one fallback hotel.
    Returns the final results (including if single or multiple hotels found).
    """
    if "HotelFacilities" in filters and not isinstance(filters["HotelFacilities"], list):
        filters["HotelFacilities"] = [filters["HotelFacilities"]]

    recorded_hotel = None

    while True:
        results = apply_filters(hotels_df, filters)

        if not results.empty:
            recorded_hotel = results.head(1)

        if results.empty:
            if recorded_hotel is not None and not recorded_hotel.empty:
                hotel_name = recorded_hotel.iloc[0].get("HotelName", "Unknown Hotel")
                print("No new results found. Returning the last recorded hotel:")
                print("--------------------------------------------------")
                print(f"The recommended hotel is: {hotel_name}")
                print("--------------------------------------------------")
                return recorded_hotel
            else:
                print("No results found and no fallback hotel available.")
                return None

        if len(results) == 1:
            # Final single hotel found
            hotel_name = results.iloc[0].get("HotelName", "Unknown Hotel")
            print("Final match found:")
            print("--------------------------------------------------")
            print(f"The recommended hotel is: {hotel_name}")
            print("--------------------------------------------------")
            return results

        # Multiple matches, ask for refinement
        print(f"Multiple matches found ({len(results)}). Please refine your search criteria.")
        user_input = input("Enter additional requirements (e.g., 'parking', 'free wifi', etc.):\n")
        additional_filters = parse_user_input(user_input, column_names).get("filters", {})
        if "HotelFacilities" in additional_filters:
            if "HotelFacilities" not in filters:
                filters["HotelFacilities"] = []
            filters["HotelFacilities"].append(additional_filters["HotelFacilities"])
        else:
            filters.update(additional_filters)

def run_hotel_search(file_path, user_query):
    """
    Runs the hotel search process using the user's original query.
    Returns the final search results (None, single DataFrame, or multiple).
    """
    hotels_data = load_data(file_path)
    if hotels_data is None:
        return None

    column_names = hotels_data.columns.tolist()
    initial_filters = parse_user_input(user_query, column_names).get("filters", {})
    results = iterative_filtering(hotels_data, initial_filters, column_names)
    return results

# %%
# 初始化研发辅助系统的环境设置，包括加载环境变量、初始化 LLM、构建向量数据库等

import os
from dotenv import load_dotenv
from langchain.chat_models import ChatOpenAI
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# 步骤 1: 加载环境变量
load_dotenv()  # 自动加载 .env 文件中的环境变量
openai_api_key = os.getenv("OPENAI_API_KEY")
if not openai_api_key:
    raise ValueError("请在 .env 文件中设置 OPENAI_API_KEY")

# 步骤 2: 初始化 LLM 和 嵌入模型
llm = ChatOpenAI(temperature=0, openai_api_key=openai_api_key)
embeddings = OpenAIEmbeddings(model="text-embedding-ada-002", openai_api_key=openai_api_key)

# 步骤 3: 加载并拆分本地文本文件
#file_path = r"C:\Users\ryan0\OneDrive\Obsidian_Lib\11_GWU\13_24FA\CSCI_6365_A_ML\20241113_AML_Final_Proj\data\attraction_resource\DC_attraction.txt"
file_path = r"C:\Users\ryan0\OneDrive\Obsidian_Lib\11_GWU\13_24FA\CSCI_6365_A_ML\20241113_AML_Final_Proj\data\attraction_resource\hotel_info.txt"
loader = TextLoader(file_path=file_path, encoding="utf8")
docs = loader.load()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
all_splits = text_splitter.split_documents(docs)

# 步骤 4: 创建向量存储
vector_store = FAISS.from_documents(all_splits, embeddings)

# 步骤 5: 定义检索函数
def run_external_search(query: str) -> str:
    """
    使用 FAISS 向量存储检索与 query 相关的文本，并返回检索结果字符串。
    """
    retrieved_docs = vector_store.similarity_search(query, k=3)
    external_results = "\n\n".join(doc.page_content for doc in retrieved_docs)
    return external_results

print("环境初始化完成。可以使用 run_external_search(query) 来进行检索。")
# Out:
# C:\Users\ryan0\AppData\Local\Temp\ipykernel_12096\3929163188.py:18: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI(temperature=0, openai_api_key=openai_api_key)
# C:\Users\ryan0\AppData\Local\Temp\ipykernel_12096\3929163188.py:19: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings(model="text-embedding-ada-002", openai_api_key=openai_api_key)
# 环境初始化完成。可以使用 run_external_search(query) 来进行检索。

# %%
def retrieve(state: State):
    """
    Determine if the user's query is hotel-related. If yes, run hotel search.
    Otherwise, do the existing retrieval logic.
    If a single hotel is found, store its info in state["context"] and hotel name in state["hotel_found"].
    """
    is_hotel_related = llm_intent_classification(state["question"])
    # Do not clear context here anymore, to maintain memory of previously found hotels
    if "context" not in state:
        state["context"] = []
    if "hotel_found" not in state:
        state["hotel_found"] = ""

    if is_hotel_related:
        print("System: Detected hotel-related query. Running hotel search...")
        file_path = r"G:\Code\Projects\GWU\24_FA\AML\Final_proj\hotels_sampled.csv"
        results = run_hotel_search(file_path, state["question"])

        if results is not None and len(results) == 1:
            hotel_info = results.iloc[0].to_dict()
            hotel_name = hotel_info.get("HotelName", "N/A")
            state["hotel_found"] = hotel_name
            context_str = (
                f"Hotel Name: {hotel_name}\n"
                f"Rating: {hotel_info.get('HotelRating','N/A')}\n"
                f"Attractions Nearby: {hotel_info.get('Attractions','N/A')}\n"
                f"Description: {hotel_info.get('Description','N/A')}\n"
                f"Facilities: {hotel_info.get('HotelFacilities','N/A')}\n"
                f"Phone: {hotel_info.get('PhoneNumber','N/A')}\n"
                f"Website: {hotel_info.get('HotelWebsiteUrl','N/A')}"
            )
            # Append the found hotel info to context if it's not already there
            if context_str not in state["context"]:
                state["context"].append(context_str)
        # If multiple hotels or None, no single hotel to record here.
    else:
        print("System: Detected non-hotel-related query. Running external web search...")
        #local_txt_file_path = r"C:\Users\ryan0\OneDrive\Obsidian_Lib\11_GWU\13_24FA\CSCI_6365_A_ML\20241113_AML_Final_Proj\data\attraction_resource\DC_attraction.txt"

        external_results = run_external_search(state["question"])
        if external_results not in state["context"]:
            state["context"].append(external_results)
    
    return state

def generate(state: State):
    """
    Generates an answer by combining the user question and retrieved context.
    If we have a single hotel in context, this will summarize that info.
    """
    if not state["context"]:
        state["answer"] = "I'm sorry, I couldn't find any relevant information."
        return state
    
    context_str = "\n".join(state["context"])
    prompt_text = f"""
    you are a travel agent,Based on the user's question and the following information, provide a helpful answer.

    User Question: "{state['question']}"
    Retrieved Information:
    {context_str}

    Answer:
    """
    response = llm.invoke(prompt_text)
    state["answer"] = response.content.strip()
    return state

# %%
def chat():
    """
    Simulates a continuous conversation loop.
    """
    print("Welcome to the Travel Assistant! Type 'exit' or 'quit' to end the conversation.")
    # Add hotel_announcement_done to track if we've printed the congratulatory message
    state = State(question="", context=[], answer="", hotel_found="")
    state["hotel_announcement_done"] = False

    while True:
        user_input = input("User: ")
        if user_input.lower() in ["exit", "quit"]:
            print("Travel Assistant: Thank you for using the Travel Assistant. Goodbye!")
            break
        
        state["question"] = user_input
        
        # Retrieve relevant information based on intent
        previous_hotel_found = state.get("hotel_found", "")
        state = retrieve(state)
        current_hotel_found = state.get("hotel_found", "")

        # Check if we have just found a hotel for the first time
        if current_hotel_found and not state["hotel_announcement_done"]:
            hotel_name = current_hotel_found
            print(f"Congrats, we found you a hotel: {hotel_name}, what else do you want to know?")
            # Mark that we've shown the announcement
            state["hotel_announcement_done"] = True
            # Do not generate LLM response this turn, as per requirement
        else:
            # Determine if the current query is hotel-related
            is_hotel_related = llm_intent_classification(state["question"])
            if not is_hotel_related:
                # Non-hotel query
                print("System: Detected non-hotel-related query. Searching attractions database...")
                # You can implement additional non-hotel logic here if desired.
            
            if state["context"]:
                state = generate(state)
                print(f"Travel Assistant: {state['answer']}\n")

        # Reset answer only (keep context and hotel_found for future queries)
        state["answer"] = ""

# %%
chat()
# Out:
# Welcome to the Travel Assistant! Type 'exit' or 'quit' to end the conversation.
# Intent Classification Result: Yes
# System: Detected hotel-related query. Running hotel search...
# --------------------------------------------------
# Dataset loaded successfully!
# Available columns in the dataset:
# ['countyCode', 'countyName', 'cityCode', 'cityName', 'HotelCode', 'HotelName', 'HotelRating', 'Address', 'Attractions', 'Description', 'FaxNumber', 'HotelFacilities', 'Map', 'PhoneNumber', 'PinCode', 'HotelWebsiteUrl']
# --------------------------------------------------
# C:\Users\ryan0\AppData\Local\Temp\ipykernel_12096\1176334614.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str).apply(lambda x: "\n".join(textwrap.wrap(x, width=width)))
# --------------------------------------------------
# Applying filters to the dataset...
# Current filters: {'cityName': 'New York'}
# Number of results found: 37
# --------------------------------------------------
# Sample of the matched results:
#                                      HotelName HotelRating                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Attractions                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# The Penthouse Organic & Modern in Times Square   ThreeStar Distances are calculated in a straight line from the property&apos;s location to\nthe point of interest or attraction  and may not reflect actual travel distance.\n&lt;br /&gt;&lt;br /&gt; Distances are displayed to the nearest 0.1 mile and\nkilometer. &lt;p&gt;Times Square - 0 km / 0 mi &lt;br /&gt;Broadway - 0.2 km /\n0.1 mi &lt;br /&gt;Town Hall - 0.2 km / 0.1 mi &lt;br /&gt;Lyceum Theatre - 0.2\nkm / 0.1 mi &lt;br /&gt;Palace Theatre - 0.3 km / 0.2 mi &lt;br /&gt;Bryant Park\n- 0.4 km / 0.3 mi &lt;br /&gt;Lyric - 0.5 km / 0.3 mi &lt;br /&gt;New York\nPublic Library - 0.6 km / 0.3 mi &lt;br /&gt;Frames Bowling Lounge - 0.6 km /\n0.4 mi &lt;br /&gt;Radio City Music Hall - 0.7 km / 0.4 mi &lt;br\n/&gt;Macy&apos;s - 0.7 km / 0.4 mi &lt;br /&gt;Rockefeller Center - 0.7 km / 0.4\nmi &lt;br /&gt;Ed Sullivan Theater - 0.8 km / 0.5 mi &lt;br /&gt;St.\nPatrick&apos;s Cathedral - 0.8 km / 0.5 mi &lt;br /&gt;Empire State Building -\n0.9 km / 0.5 mi &lt;br /&gt;&lt;/p&gt;&lt;p&gt;The nearest airports are:&lt;br\n/&gt;New York  NY (JRB-Downtown Manhattan Heliport) - 6.4 km / 4 mi&lt;br\n/&gt;New York  NY (LGA-LaGuardia) - 9.8 km / 6.1 mi&lt;br /&gt;Newark  NJ (EWR-\nLiberty Intl.) - 17.7 km / 11 mi&lt;br /&gt;New York  NY (JFK-John F. Kennedy\nIntl.) - 21.3 km / 13.2 mi&lt;br /&gt;&lt;/p&gt;&lt;p&gt;The preferred airport\nfor The Penthouse Organic &amp; Modern in Times Square is New York  NY (LGA-\nLaGuardia). &lt;/p&gt;                                                                                                                                                                                                                                                <p><b>Property Location</b> <br />With a stay at The Penthouse Organic & Modern\nin Times Square in New York (Broadway - Times Square), you''ll be minutes from\nToys ''R'' Us Times Square and Times Square. This apartment is close to Broadway\nand Macy''s.</p><p><b>Rooms</b> <br />Make yourself at home in one of the 2 air-\nconditioned rooms featuring kitchenettes with full-sized refrigerators/freezers\nand stovetops. Wired and wireless Internet access is complimentary, and flat-\nscreen televisions with cable programming provide entertainment. Conveniences\ninclude desks and microwaves, as well as phones with free local\ncalls.</p><p><b>Rec, Spa, Premium Amenities</b> <br />Take advantage of\nrecreation opportunities such as an indoor pool or take in the view from a\nrooftop terrace and a terrace. This apartment also features complimentary\nwireless Internet access, an arcade/game room, and a television in the lobby.\nGuests can catch a ride to nearby destinations on the complimentary area\nshuttle.</p><p><b>Business, Other Amenities</b> <br />Featured amenities include\ncomplimentary high-speed (wired) Internet access, a business center, and a\ncomputer station. Self parking (subject to charges) is available onsite.</p>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Computer station Meeting rooms Private bathrooms Air Condition in rooms Indoor\npool Cookware  dishware  utensil-cutlery Microwave Limited Time Reception\nBathtub/Shower Combination Separate living room Non-Smoking Hotel HD TV Free\nWireless Internet access Cable / Satellite Television Free Wireless Internet\naccess (inroom) Tea/Cof ...
#                                    Visions Inn   ThreeStar                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        nan                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Just 100 metres from the National Baseball Hall of Fame and Museum, this\nCooperstown inn is housed in a former 19th-century brewery. Lake Otsego is less\nthan 5 minutes’ walk away.  A cable TV and a seating area are provided in each\nroom at Visions Inn. Guests are also provided with a private entrance and an en\nsuite bathroom that comes with a hairdryer.  Visions Inn also provides free\nparking. During the summer, guests can enjoy a hot breakfast served at the\nnearby Lake Front Hotel, 3 minutes walk away.   Doubleday Field is just 400\nmetres from Visions Inn, which is only 15 minutes’ drive from Brewery Ommegang.\nGlimmerglass State Park is 13 minutes’ drive away. Guests are required to show a\nphoto identification and credit card upon check-in. Please note that all Special\nRequests are subject to availability and additional charges may apply. Please\nnote, guests must check in at the main office, located at the Lake Front Hotel\nat 10 Fair Street.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        linens  towels and laundry washed in accordance with local authority guidelines\nguest accommodation is disinfected between stays staff follow all safety\nprotocols as directed by local authorities shared stationery such as printed\nmenus  magazines  pens  and paper removed hand sanitizer in guest accommodation\nand key areas cashless payment available physical distancing rules followed\nscreens or physical barriers placed between staff and guests in appropriate\nareas invoice provided guests have the option to cancel ...
#                     Riviera Motor Inn Brooklyn     OneStar                                                                                                                                                                                                                                         Distances are displayed to the nearest 0.1 mile and kilometer. <br /> <p>Resorts\nWorld Casino - 4.9 km / 3.1 mi <br /> Prospect Park - 7.2 km / 4.5 mi <br />\nBrooklyn Botanic Gardens - 7.6 km / 4.7 mi <br /> Brooklyn Museum - 8 km / 5 mi\n<br /> Barclays Center Brooklyn - 8.3 km / 5.2 mi <br /> Brooklyn Heights\nPromenade - 10.6 km / 6.6 mi <br /> Brooklyn Bridge Park - 10.7 km / 6.6 mi <br\n/> Flushing Meadows-Corona Park - 10.8 km / 6.7 mi <br /> Pace University - 12.6\nkm / 7.8 mi <br /> Aviator Sports and Events Center - 12.7 km / 7.9 mi <br />\nNew York University - 12.8 km / 7.9 mi <br /> Sunset Park - 12.9 km / 8 mi <br\n/> Washington Square Park - 13.2 km / 8.2 mi <br /> St. John s University - 13.2\nkm / 8.2 mi <br /> Wall Street - 13.2 km / 8.2 mi <br /> </p><p>The nearest\nairports are:<br />John F. Kennedy Intl. Airport (JFK) - 11.9 km / 7.4 mi<br />\nLiberty Intl. Airport (EWR) - 55.1 km / 34.2 mi<br /> LaGuardia Airport (LGA) -\n19.7 km / 12.3 mi<br /> New York  NY (NYS-Skyports Seaplane Base) - 27.6 km /\n17.1 mi<br /> Teterboro  NJ (TEB) - 35 km / 21.7 mi<br /> </p><p>The preferred\nairport for Riviera Motor Inn Brooklyn is John F. Kennedy Intl. Airport (JFK).\n</p>                                                                                                                                                                                                                                                                                                                                                                                                                                                                          <p>HeadLine : In Brooklyn (Cypress Hills)</p><p>Location : Located in Brooklyn\n(Cypress Hills), Riviera Motor Inn Brooklyn is within a 10-minute drive of\nProspect Park and Flushing Meadows-Corona Park.  This motel is 5.2 mi (8.3 km)\nfrom Barclays Center Brooklyn and 6.6 mi (10.7 km) from Brooklyn Bridge\nPark.</p><p>Rooms : Make yourself at home in one of the 42 air-conditioned\nguestrooms. Complimentary wireless Internet access keeps you connected, and\ncable programming is available for your entertainment. Bathrooms with shower/tub\ncombinations are provided.</p><p>CheckIn Instructions : Extra-person charges may\napply and vary depending on property policy Government-issued photo\nidentification and a credit card, debit card, or cash deposit may be required at\ncheck-in for incidental charges Special requests are subject to availability\nupon check-in and may incur additional charges; special requests cannot be\nguaranteed</p><p>Special Instructions : Front desk staff will greet guests on\narrival.</p>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
#                                Villa Florencia         All                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        nan Located in Bridgehampton, Villa Florencia - Luxuriant 11 Bedroom Villa provides\naccommodation with a private pool. The air-conditioned accommodation is 34 km\nfrom Riverhead, and guests benefit from private parking available on site and\nfree WiFi.  The villa features 11 bedrooms, a flat-screen TV, an equipped\nkitchen with a microwave and a fridge, a washing machine, and 1 bathroom with a\nhot tub.  The villa offers a terrace. A garden, barbecue and an outdoor swimming\npool are featured at Villa Florencia.  Montauk is 34 km from the accommodation,\nwhile East Hampton is 12 km away. The nearest airport is Long Island MacArthur\nAirport, 73 km from Villa Florencia - Luxuriant 11 Bedroom Villa. Guests are\nrequired to show a photo identification and credit card upon check-in. Please\nnote that all Special Requests are subject to availability and additional\ncharges may apply. Please inform Villa Florencia - Luxuriant 11 Bedroom Villa in\nadvance of your expected arrival time. You can use the Special Requests box when\nbooking, or contact the property directly with the contact details provided in\nyour confirmation. This property will not accommodate hen, stag or similar\nparties.  A damage deposit of USD 2235 is required. The host charges this 7 days\nbefore arrival. This will be collected by credit card. You should be reimbursed\nwithin 14 days of check-out. Your deposit will be refunded in full via credit\ncard, subject to an inspection of the property.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
#                                      Argos Inn    FourStar                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        nan                                                                                                                                                                                                                                                                                                                                                        Housed in an historic building that has previously been the Mayor’s Mansion of\nIthaca and the Duncan-Hines world headquarters, this Ithaca hotel offers an on-\nsite bar. Free WiFi access is available.  Each room at Argos Inn - Ithacas\nBoutique Hotel is decked out in a blend of historic details and modern\namenities. Rooms offer geothermal heating and air conditioning. Each en suite\nbathroom features a hairdryer and select bathrooms are equipped with a heated\nstone slab floor.  The environmentally-friendly Argos Inn - Ithacas Boutique\nHotel offers a sun porch and an outdoor stone patio.  Bar Argos, located on\nsite, serves up classic cocktails, local beer and wine for guests. Design\nfeatures include a belle époque zinc bar and custom-made furniture.  Cornell\nUniversity is just 1.4 km from the hotel.  Ithaca College is 3 minutes’ drive\naway. Guests are required to show a photo identification and credit card upon\ncheck-in. Please note that all Special Requests are subject to availability and\nadditional charges may apply. It is not possible to stay at this property for\nCoronavirus (COVID-19) quarantine purposes. Terrace Non-smoking rooms Business centre Facilities for disabled guests Free\nparking internet services Solarium Hiking Heating Fax/photocopying Luggage\nstorage wifi Allergy-free room Parking meeting/banquet facilities Bar Golf\ncourse (within 3 km) Free WiFi Non-smoking throughout Air conditioning\ndesignated smoking area concierge service Private check-in/check-out shared\nlounge/TV area Adult only Daily housekeeping parking on site Private parking\nwifi available in all areas board games/puzzles Accessible parking Wheelchair\naccessible Toilet with grab rails Wine/champagne coffee house on site Outdoor\nfurniture Picnic area temporary art galleries Live music/performance Key access\nSmoke alarms Fire extinguishers use of cleaning chemicals that are effective\nagainst coronavirus linens  towels and laundry washed in accordance with local\nauthority guidelines guest accommodation is disinfected between stays guest\naccommodation sealed after cleaning staff follow all safety protocols as\ndirected by local au ...
# --------------------------------------------------
# Multiple matches found (37). Please refine your search criteria.
# C:\Users\ryan0\AppData\Local\Temp\ipykernel_12096\1176334614.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str).apply(lambda x: "\n".join(textwrap.wrap(x, width=width)))
# --------------------------------------------------
# Applying filters to the dataset...
# Current filters: {'cityName': 'New York', 'HotelRating': 'FourStar'}
# Number of results found: 5
# --------------------------------------------------
# Sample of the matched results:
#                   HotelName HotelRating                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Attractions                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
#                   Argos Inn    FourStar                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       nan                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Housed in an historic building that has previously been the Mayor’s Mansion of\nIthaca and the Duncan-Hines world headquarters, this Ithaca hotel offers an on-\nsite bar. Free WiFi access is available.  Each room at Argos Inn - Ithacas\nBoutique Hotel is decked out in a blend of historic details and modern\namenities. Rooms offer geothermal heating and air conditioning. Each en suite\nbathroom features a hairdryer and select bathrooms are equipped with a heated\nstone slab floor.  The environmentally-friendly Argos Inn - Ithacas Boutique\nHotel offers a sun porch and an outdoor stone patio.  Bar Argos, located on\nsite, serves up classic cocktails, local beer and wine for guests. Design\nfeatures include a belle époque zinc bar and custom-made furniture.  Cornell\nUniversity is just 1.4 km from the hotel.  Ithaca College is 3 minutes’ drive\naway. Guests are required to show a photo identification and credit card upon\ncheck-in. Please note that all Special Requests are subject to availability and\nadditional charges may apply. It is not possible to stay at this property for\nCoronavirus (COVID-19) quarantine purposes. Terrace Non-smoking rooms Business centre Facilities for disabled guests Free\nparking internet services Solarium Hiking Heating Fax/photocopying Luggage\nstorage wifi Allergy-free room Parking meeting/banquet facilities Bar Golf\ncourse (within 3 km) Free WiFi Non-smoking throughout Air conditioning\ndesignated smoking area concierge service Private check-in/check-out shared\nlounge/TV area Adult only Daily housekeeping parking on site Private parking\nwifi available in all areas board games/puzzles Accessible parking Wheelchair\naccessible Toilet with grab rails Wine/champagne coffee house on site Outdoor\nfurniture Picnic area temporary art galleries Live music/performance Key access\nSmoke alarms Fire extinguishers use of cleaning chemicals that are effective\nagainst coronavirus ...
# New York Marriott East Side    FourStar                                                         Distances are displayed\nto the nearest 0.1 mile and kilometer. <br /> <p>5th Avenue - 0.3 km / 0.2 mi\n<br /> Chrysler Building - 0.5 km / 0.3 mi <br /> Grand Central Terminal - 0.6\nkm / 0.4 mi <br /> St. Patrick s Cathedral - 0.7 km / 0.4 mi <br /> Rockefeller\nCenter - 0.8 km / 0.5 mi <br /> Madison Avenue - 0.8 km / 0.5 mi <br /> Top of\nthe Rock - 0.8 km / 0.5 mi <br /> United Nations Headquarters - 0.9 km / 0.6 mi\n<br /> Museum of Modern Art - 1 km / 0.6 mi <br /> Radio City Music Hall - 1 km\n/ 0.6 mi <br /> Times Square - 1 km / 0.6 mi <br /> Winter Garden Theatre - 1.3\nkm / 0.8 mi <br /> Ambassador Theatre - 1.3 km / 0.8 mi <br /> Central Park -\n1.3 km / 0.8 mi <br /> Broadway - 1.3 km / 0.8 mi <br /> </p><p>The nearest\nairports are:<br />LaGuardia Airport (LGA) - 16.8 km / 10.4 mi<br /> John F.\nKennedy Intl. Airport (JFK) - 27.5 km / 17.1 mi<br /> Liberty Intl. Airport\n(EWR) - 27.9 km / 17.4 mi<br /> New York  NY (NYS-Skyports Seaplane Base) - 2.9\nkm / 1.8 mi<br /> Teterboro  NJ (TEB) - 20 km / 12.4 mi<br /> </p><p>The\npreferred airport for New York Marriott East Side is LaGuardia Airport (LGA).\n</p> <p>HeadLine : Near Chrysler Building</p><p>Location : With a stay at New York\nMarriott East Side, you ll be centrally located in New York, just a 4-minute\nwalk from 5th Avenue and 6 minutes by foot from Chrysler Building.  This 4-star\nhotel is 0.4 mi (0.6 km) from Grand Central Terminal and 0.4 mi (0.7 km) from\nSt. Patrick s Cathedral.</p><p>Rooms : Make yourself at home in one of the 655\nair-conditioned rooms featuring iPod docking stations and LCD televisions. Cable\nprogramming provides entertainment, and wired and wireless Internet access is\navailable for a surcharge. Private bathrooms with showers feature complimentary\ntoiletries and hair dryers. Conveniences include phones, as well as safes and\ndesks.</p><p>Dining : Enjoy American cuisine at 525LEX Restaurant Lounge, a\nrestaurant which features a bar/lounge, or stay in and take advantage of the\n24-hour room service. To-go breakfasts are available daily from 6:30 AM to 11:00\nAM for a fee.</p><p>Renovations : This property is closed from March 23 2020 to\nAugust 31 2020 (dates subject to change).</p><p>CheckIn Instructions : Extra-\nperson charges may apply and vary depending on property policy. <br\n/>Government-issued photo identification and a credit card, debit card, or cash\ndeposit may be required at check-in for incidental charges. <br />Special\nrequests are subject to availability upon check-in and may incur additional\ncharges. Special requests cannot be guaranteed. <ul> <li>This property advises\nthat enhanced cleaning and guest safety measures are currently in\nplace.</li><li>Disinfectant is used to clean the property.</li><li>The property\naffirms that it follows sanitization practices of Commitment to Clean (Marriott)\nguidelines.</li>Please note that cultural norms and guest policies may differ by\ncountry and by property. The policies listed are provided by the property.\n</ul></p><p>Special Instructions : Front desk staff will greet guests on\narrival.</p>                                                                                                                                                                                                                            Wheelchair-accessible on-site restaurant Express check-in Wheelchair-accessible\nlounge Visual alarms in hallways Bar/lounge elevator 24-hour front desk\nRestaurant Express check-out Dry cleaning/laundry service Valet parking\n(surcharge) Computer station Conference space size (meters) - 1737 Number of\nmeeting rooms - 20 Terrace Luggage storage ATM/banking Concierge services Gift\nshops or newsstand Snack bar/deli Wheelchair accessible (may have limitations)\nFirepit Conference space Grocery/convenience store Coffee shop or café - 1 Free\nWiFi Smoke-free property Safe ...
#       LaGuardia Plaza Hotel    FourStar                                                                                  Distances are displayed to the nearest 0.1 mile and kilometer. <br />\n<p>Flushing Meadows-Corona Park - 2.5 km / 1.5 mi <br /> Citi Field - 2.6 km /\n1.6 mi <br /> USTA Billie Jean King National Tennis Center - 3.4 km / 2.1 mi <br\n/> Arthur Ashe Stadium - 3.5 km / 2.2 mi <br /> Roosevelt Island - 9.6 km / 5.9\nmi <br /> Apollo Theater - 11.3 km / 7 mi <br /> 5th Avenue - 11.9 km / 7.4 mi\n<br /> St. Patrick s Cathedral - 12.1 km / 7.5 mi <br /> Mount Sinai Hospital -\n12.4 km / 7.7 mi <br /> Randall s Island Park - 12.5 km / 7.7 mi <br /> Memorial\nSloan-Kettering Cancer Center - 12.5 km / 7.8 mi <br /> Trump Tower - 12.7 km /\n7.9 mi <br /> Central Park - 12.8 km / 7.9 mi <br /> Chrysler Building - 12.9 km\n/ 8 mi <br /> Yankee Stadium - 12.9 km / 8 mi <br /> </p><p>The nearest airports\nare:<br />John F. Kennedy Intl. Airport (JFK) - 20 km / 12.4 mi<br /> Newark\nLiberty Intl. Airport (EWR) - 51.8 km / 32.2 mi<br /> LaGuardia Airport (LGA) -\n1.9 km / 1.2 mi<br /> New York  NY (NYS-Skyports Seaplane Base) - 14.9 km / 9.2\nmi<br /> MacArthur Airport (ISP) - 82.4 km / 51.2 mi<br /> </p><p></p>                                                                                                                                                                                                                                                                                              <p>HeadLine : In East Elmhurst (Queens)</p><p>Location : With a stay at\nLaGuardia Plaza Hotel in East Elmhurst (Queens), you ll be within a 15-minute\ndrive of Yankee Stadium and 5th Avenue.  This 4-star hotel is 7.9 mi (12.8 km)\nfrom Central Park and 8.1 mi (13 km) from Broadway.</p><p>Rooms : Make yourself\nat home in one of the 358 air-conditioned rooms featuring flat-screen\ntelevisions. Complimentary wireless Internet access keeps you connected, and\ncable programming is available for your entertainment. Private bathrooms with\nbathtubs or showers feature complimentary toiletries and hair dryers.\nConveniences include phones, as well as safes and coffee/tea\nmakers.</p><p>Dining : Grab a bite at Elements Lounge, one of the hotel s 2\nrestaurants, or stay in and take advantage of the room service. Snacks are also\navailable at the coffee shop/cafe. Quench your thirst with your favorite drink\nat the bar/lounge.</p><p>CheckIn Instructions : <ul>  <li>Extra-person charges\nmay apply and vary depending on property policy</li><li>Government-issued photo\nidentification and a credit card may be required at check-in for incidental\ncharges</li><li>Special requests are subject to availability upon check-in and\nmay incur additional charges; special requests cannot be guaranteed</li><li>The\nname on the credit card used at check-in to pay for incidentals must be the\nprimary name on the guestroom reservation</li><li>This property accepts credit\ncards; cash is not accepted</li><li>Safety features at this property include a\ncarbon monoxide detector and a smoke detector</li>  </ul></p><p>Special\nInstructions : Front desk staff will greet guests on arrival.</p>                                                                                                             Gift shops or newsstand Dry cleaning/laundry service Long-term parking\n(surcharge) Conference space size (meters) - 1161 Free WiFi Number of\nbars/lounges - 1 Braille or raised signage Assistive listening devices available\nNumber of indoor pools - 1 In-room accessibility (in select rooms) Tours/ticket\nassistance Accessible bathroom (in select rooms) Free shopping center shuttle\nFree airport transportation Eco-friendly toiletries Wheelchair-accessible on-\nsite restaurant No accessible shuttle Multilingual staff Handrails in stairways\nConference center Wheelchair-accessible meeting spaces/business center Number of\ncoffee shops/cafes - 1 Laundry facilities elevator Fitness  ...
#                  Boro Hotel    FourStar                                             Distances are displayed to the nearest 0.1 mile and kilometer. <br /> <p>Museum\nof the Moving Image - 1.4 km / 0.9 mi <br /> MoMA PS1 - 1.5 km / 0.9 mi <br />\nThe Foundry - 1.6 km / 1 mi <br /> Roosevelt Island - 1.7 km / 1.1 mi <br />\nNoguchi Museum - 1.9 km / 1.2 mi <br /> Memorial Sloan-Kettering Cancer Center -\n3.6 km / 2.3 mi <br /> 5th Avenue - 3.7 km / 2.3 mi <br /> Central Park Zoo -\n4.2 km / 2.6 mi <br /> United Nations Headquarters - 4.2 km / 2.6 mi <br />\nTrump Tower - 4.3 km / 2.7 mi <br /> Rockefeller Center - 4.7 km / 2.9 mi <br />\nMuseum of Modern Art - 4.7 km / 2.9 mi <br /> St. Patrick s Cathedral - 4.7 km /\n3 mi <br /> Carnegie Hall - 4.8 km / 3 mi <br /> Chrysler Building - 4.9 km /\n3.1 mi <br /> </p><p>The nearest airports are:<br />John F. Kennedy Intl.\nAirport (JFK) - 26.7 km / 16.6 mi<br /> Newark Liberty Intl. Airport (EWR) -\n33.3 km / 20.7 mi<br /> LaGuardia Airport (LGA) - 9 km / 5.6 mi<br /> New York\nNY (NYS-Skyports Seaplane Base) - 7.1 km / 4.4 mi<br /> Teterboro  NJ (TEB) -\n24.5 km / 15.2 mi<br /> </p><p>The preferred airport for The Boro Hotel is John\nF. Kennedy Intl. Airport (JFK). </p>                                                                <p>HeadLine : In Long Island City (Queens)</p><p>Location : A stay at The Boro\nHotel places you in the heart of Long Island City, within a 10-minute drive of\nMuseum of the Moving Image and Noguchi Museum.  This 4.5-star hotel is 1.1 mi\n(1.8 km) from The Foundry and 1.3 mi (2 km) from MoMA PS1.</p><p>Rooms : Make\nyourself at home in one of the 108 guestrooms featuring iPod docking stations\nand LED televisions. Your pillowtop bed comes with Egyptian cotton sheets.\nComplimentary wireless Internet access keeps you connected, and satellite\nprogramming is available for your entertainment. Private bathrooms have designer\ntoiletries and hair dryers.</p><p>Dining : Enjoy a meal at the restaurant or\nsnacks in the coffee shop/cafe. The hotel also offers room service (during\nlimited hours). Wrap up your day with a drink at the bar/lounge. Cooked-to-order\nbreakfasts are served on weekends from 8:00 AM to 11:00 AM for a\nfee.</p><p>CheckIn Instructions : <ul>  <li>Extra-person charges may apply and\nvary depending on property policy</li><li>Government-issued photo identification\nand a credit card, debit card, or cash deposit may be required at check-in for\nincidental charges</li><li>Special requests are subject to availability upon\ncheck-in and may incur additional charges; special requests cannot be\nguaranteed</li><li>Noise-free guestrooms cannot be guaranteed</li><li>Safety\nfeatures at this property include a carbon monoxide detector, a fire\nextinguisher, a smoke detector, a security system, and a first aid\nkit</li><li>Some rooms at this property are not suitable for children; please\nadd child ages in the search parameters to display available rooms</li><li>Be\nprepared: check the latest COVID-19 travel requirements and measures in place\nfor this destination before you travel.</li>  </ul></p><p>Special Instructions :\nFront desk staff will greet guests on arrival.</p>                                                                                                                                                                                                                Wheelchair-accessible on-site restaurant Library Wheelchair-accessible lounge\nelevator Fitness facilities 24-hour front desk Dry cleaning/laundry service Limo\nor Town Car service available Food and water bowls Conference space size\n(meters) - 232 Number of meeting rooms - 2 Terrace Luggage storage Concierge\nservices Snack bar/deli Designated smoking areas Wheelchair accessible (may have\nlimitations) Fireplace in lobby Coffee/tea in common areas Rooftop terrace\nNumber of bars/lounges - 1 Conference space Free WiFi Number of coffee\nshops/cafes - 1 Safe-deposit box at front de ...
#         YO1 Wellness Center    FourStar                                                                                                                                                                                                                            Distances are displayed to the nearest 0.1 mile and kilometer. <br /> <p>The\nKartrite Resort & Indoor Waterpark - 4.3 km / 2.7 mi <br /> Mongaup River - 4.7\nkm / 2.9 mi <br /> Concord Monster Golf Course - 5.1 km / 3.2 mi <br /> South\nFallsburg Hebrew Association Synagogue - 6.5 km / 4.1 mi <br /> Sullivan County\nDramatic Workshop - Rivoli Theatre - 6.7 km / 4.2 mi <br /> Monticello Casino\nand Raceway - 7 km / 4.3 mi <br /> Resorts World Catskills - 9.2 km / 5.7 mi <br\n/> Tarry Brae Golf Course - 9.3 km / 5.8 mi <br /> Holiday Mountain Ski and Fun\nPark - 11.7 km / 7.3 mi <br /> Neversink River - 12.7 km / 7.9 mi <br />\nCatskill Regional Medical Center - 12.9 km / 8 mi <br /> Crystal Run Healthcare\nRock Hill - 13.5 km / 8.4 mi <br /> Lake Louise Marie - 13.6 km / 8.4 mi <br />\nNeversink Dam - 17.9 km / 11.1 mi <br /> Forestburgh Playhouse - 19.5 km / 12.1\nmi <br /> </p><p>The nearest major airport is Stewart Intl. Airport (SWF) - 64.4\nkm / 40 mi</p>                                                                                                                                                                                                                                                                                                                                                                                   <p>HeadLine : On a lake</p><p>Location : With a stay at YO1 Longevity & Health\nResorts, Catskills in Monticello, you ll be 3.2 mi (5.1 km) from Concord Monster\nGolf Course and 14.4 mi (23.2 km) from Bethel Woods Center For The Arts.  This\n4-star hotel is 14.9 mi (24 km) from Sullivan County Golf and Country Club and\n24.8 mi (39.8 km) from Catskill Mountains.</p><p>Rooms : Make yourself at home\nin one of the 131 air-conditioned rooms featuring flat-screen televisions. Your\npillowtop bed comes with premium bedding. Complimentary wireless Internet access\nis available to keep you connected. Private bathrooms with bathtubs or showers\nfeature rainfall showerheads and designer toiletries.</p><p>Dining : Stop by the\nhotel s restaurant, Restaurant, for lunch or dinner, or grab snacks at the 2\ncoffee shops/cafes. Buffet breakfasts are available daily from 7:00 AM to 10:30\nAM for a fee.</p><p>CheckIn Instructions : <ul>  <li>Extra-person charges may\napply and vary depending on property policy</li><li>Government-issued photo\nidentification and a credit card, debit card, or cash deposit may be required at\ncheck-in for incidental charges</li><li>Special requests are subject to\navailability upon check-in and may incur additional charges; special requests\ncannot be guaranteed</li><li>This property accepts credit cards, debit cards,\nand cash</li><li>Parties and events are allowed on site</li><li>Safety features\nat this property include a carbon monoxide detector and a smoke detector</li>\n</ul></p><p>Special Instructions : Front desk staff will greet guests on\narrival.</p>                                                               Yoga classes/instruction on site Art gallery on site 24-hour health club Walkway\nto water Designer stores on site Luggage storage Porter/bellhop Business center\n24-hour front desk Library Gift shops or newsstand Dry cleaning/laundry service\nShopping on site Lockers available Outdoor furniture Number of meeting rooms - 5\nCoworking spaces Swimming pool Free WiFi Number of spa tubs - 1 Number of indoor\npools - 1 In-room accessibility (in select rooms) Wheelchair accessible parking\nRoll-in shower (in select rooms) Accessible bathroom (in select rooms) Fireplace\nin lobby Fitness classes on site Multilingual staff Conference center Water\ndispenser Breakfast available (surcharge) Wheelchair-accessible meeting\nspaces/busi ...
# --------------------------------------------------
# Multiple matches found (5). Please refine your search criteria.
# C:\Users\ryan0\AppData\Local\Temp\ipykernel_12096\1176334614.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str).apply(lambda x: "\n".join(textwrap.wrap(x, width=width)))
# --------------------------------------------------
# Applying filters to the dataset...
# Current filters: {'cityName': 'New York', 'HotelRating': 'FiveStar'}
# Number of results found: 1
# --------------------------------------------------
# Sample of the matched results:
#                   HotelName HotelRating Attractions                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       HotelFacilities PhoneNumber                                                   HotelWebsiteUrl
# Collective Governors Island    FiveStar         nan With Barclays Center reachable in 5.1 km, Collective Governors Island features\naccommodation, a restaurant, a garden, a shared lounge and a terrace.\nComplimentary WiFi is offered throughout the property.  There is a private\nbathroom with shower in some units, along with free toiletries, a hairdryer and\nslippers.  National September 11 Memorial & Museum is 6.3 km from the camping,\nwhile One World Trade Center is 6.5 km from the property. The nearest airport is\nJohn F. Kennedy International Airport, 21 km from Collective Governors Island.\nGuests are required to show a photo identification and credit card upon check-\nin. Please note that all Special Requests are subject to availability and\nadditional charges may apply. Please inform Collective Governors Island in\nadvance of your expected arrival time. You can use the Special Requests box when\nbooking, or contact the property directly with the contact details provided in\nyour confirmation. In response to Coronavirus (COVID-19), additional safety and\nsanitation measures are in effect at this property. Daily housekeeping wifi available in all areas board games/puzzles Kid meals\nRestaurant meeting/banquet facilities Bar Garden Terrace Non-smoking rooms\nFacilities for disabled guests internet services Safety Deposit Box Massage BBQ\nfacilities Heating wifi Allergy-free room Free WiFi Non-smoking throughout Air\nconditioning Snack Bar Sun terrace concierge service Special diet menus (on\nrequest) shared lounge/TV area Evening entertainment guests have the option to\ncancel any cleaning services for their accommodation during their stay all\nplates  cutlery  glasses and other tableware have been sanitized property is\ncleaned by professional cleaning companies invoice provided screens or physical\nbarriers placed between staff and guests in appropriate areas physical\ndistancing rules followed cashless payment available contactless check-in/check-\nout first aid kit available process in place to check health of guests hand\nsanitizer in guest accommodation and key areas shared stationery such as printed\nmenus  magazines  pens  and paper removed staff follow all safety protocols as\ndirected by local authorities food can be delivered to guest accommodation\nphysical distancing in dining areas guest accommodation sealed after cleaning\nThemed dinner nights Bike tours Walking tours Movie nights fitness classes Yoga\nclasses Fitness Spa/wellness packages guest accommodation is disinfected between\nstays linens  towels and laundry washed in accordance with local authority\nguidelines use of cleaning chemicals that are effective against coronavirus\n24-hour security Live music/performance Cooking class Tour or class about local\nculture Happy hour Outdoor fireplace Picnic area Outdoor furniture coffee house\non site Wine/champagne Wheelchair accessible Kid-friendly buffet         NaN https://www.booking.com/hotel/us/collective-governors-island.html
# --------------------------------------------------
# Final match found:
# --------------------------------------------------
# The recommended hotel is: Collective Governors Island
# --------------------------------------------------
# Congrats, we found you a hotel: Collective Governors Island, what else do you want to know?
# Intent Classification Result: No
# System: Detected non-hotel-related query. Running external web search...
# Intent Classification Result: No
# System: Detected non-hotel-related query. Searching attractions database...
# Travel Assistant: To contact Collective Governors Island, you can reach out to them via email at hello@collectiveretreats.com or by phone at (970) 445-2033. You can also visit their website at https://www.booking.com/hotel/us/collective-governors-island.html for more information and to make reservations.
#
# Intent Classification Result: No
# System: Detected non-hotel-related query. Running external web search...
# Intent Classification Result: No
# System: Detected non-hotel-related query. Searching attractions database...
# Travel Assistant: To get to Collective Governors Island, you can take the Governors Island Ferry departing daily from Lower Manhattan and Brooklyn. The island is car-free, so it is best explored by foot or bicycle. You can also reach the island from local airports such as Newark International, LaGuardia, and JFK by taking public transportation or a taxi to the 10 South Street Ferry Terminal and then taking the Governors Island Ferry. Enjoy your stay at this peaceful oasis with endless opportunities for discovery and relaxation.
#
# Intent Classification Result: No
# System: Detected non-hotel-related query. Running external web search...
# Intent Classification Result: No
# System: Detected non-hotel-related query. Searching attractions database...
# Travel Assistant: At Collective Governors Island, you can enjoy a variety of activities such as morning yoga, spa offerings, live music, cocktail hour on the sunset terrace, chef-driven farm-to-table dining, and exploring historic Governor's Island by bike. The gourmet dining experience offers a contemporary American menu with a focus on wood flame grilling. Additionally, guests can relax in the peaceful oasis and take advantage of the expansive outdoor setting. To get to Collective Governors Island, you can take the Governors Island Ferry departing daily from Lower Manhattan and Brooklyn. Enjoy your stay!
#
# Intent Classification Result: No
# System: Detected non-hotel-related query. Running external web search...
# Intent Classification Result: No
# System: Detected non-hotel-related query. Searching attractions database...
# Travel Assistant: Thank you for your interest in Collective Governors Island. If you have any further questions or need assistance with booking, feel free to reach out to us at hello@collectiveretreats.com or call (970) 445-2033. Have a great day!
#
# Travel Assistant: Thank you for using the Travel Assistant. Goodbye!
